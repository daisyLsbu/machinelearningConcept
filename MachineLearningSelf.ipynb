# %%
#code cell - to write executable code

# %% [markdown]
# Mark down cell - for headings, use # at begining

# %% [raw]
# Raw cell - to desplay text as it is

# %% [markdown]
# # Numphy

# %% [raw]
# Mathematical and logical operations on arrays.
# Fourier transformation
# Operations associated with linear algebra.

# %%
import numpy as np

# %% [markdown]
# # Pandas

# %% [raw]
# Load
# Prepare
# Manipulate
# Model
# Analyze

# %%
import pandas as pd

# %%
import pandas as pd

import numpy as np

data = np.array(['d','a','i','s','y'])
print (data)

s = pd.Series(data)
print (s)
# Out:
# ['d' 'a' 'i' 's' 'y']
# 0    d
# 1    a
# 2    i
# 3    s
# 4    y
# dtype: object

# %% [markdown]
# # Scikit-learn

# %%
from sklearn.datasets import load_breast_cancer

# %% [markdown]
# # DATA : loading in the project

# %% [raw]
# with csv reader

# %%
import csv
import numpy as np
#path = r"c:\iris.csv"
path = r"iris.csv"
with open(path,'r') as f:
   reader = csv.reader(f,delimiter = ',')
   headers = next(reader)
   data = list(reader)
   data = np.array(data)
print(headers)
print(data.shape)
print(data[:3])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 5
#       3 #path = r"c:\iris.csv"
#       4 path = r"iris.csv"
# ----> 5 with open(path,'r') as f:
#       6    reader = csv.reader(f,delimiter = ',')
#       7    headers = next(reader)
#
# File d:\workspace\MachineLearning\venv\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'iris.csv'

# %% [raw]
# with numpy

# %%
from numpy import loadtxt
path = r"iris.csv"
datapath= open(path, 'r')
#not able to convert to float
#data = loadtxt(datapath, delimiter=',')
#print(data.shape)
#print(data[:3])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 from numpy import loadtxt
#       2 path = r"iris.csv"
# ----> 3 datapath= open(path, 'r')
#       4 #not able to convert to float
#       5 #data = loadtxt(datapath, delimiter=',')
#       6 #print(data.shape)
#       7 #print(data[:3])
#
# File d:\workspace\MachineLearning\venv\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'iris.csv'

# %% [raw]
# with Pandas

# %%
from pandas import read_csv
path = r"iris.csv"
data = read_csv(path)
print(data.shape)
print(data[:3])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 from pandas import read_csv
#       2 path = r"iris.csv"
# ----> 3 data = read_csv(path)
#       4 print(data.shape)
#       5 print(data[:3])
#
# ...

# %%
from pandas import read_csv
path = r"iris.csv"
headernames = ['preg', 'plas', 'pres', 'skin', 'test', 'mass']
data = read_csv(path, names=headernames)
print(data.shape)
print(data[:3])
# Out:
# (151, 6)
#   preg           plas          pres           skin          test         mass
# 0   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1    1            5.1           3.5            1.4           0.2  Iris-setosa
# 2    2            4.9           3.0            1.4           0.2  Iris-setosa

# %% [markdown]
# # understanding data

# %%
print(data.dtypes)
# Out:
# preg    object
# plas    object
# pres    object
# skin    object
# test    object
# mass    object
# dtype: object

# %%
print(data.describe())
# Out:
#        preg plas pres skin test         mass
# count   151  151  151  151  151          151
# unique  151   36   24   44   23            4
# top      Id  5.0  3.0  1.5  0.2  Iris-setosa
# freq      1   10   26   14   28           50

# %%
#Reviewing Distribution
count_class = data.groupby('mass').size()
print(count_class)
# Out:
# mass
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Species             1
# dtype: int64
